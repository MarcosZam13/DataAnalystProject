# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import glob

ruta = "/content/drive/MyDrive/ProyectoAnálisis/*.csv"

files = glob.glob(ruta)

dataframes = []

for file in files:
    df = pd.read_csv(file)
    df["source_file"] = file.split("/")[-1]  # opcional
    dataframes.append(df)

print(f"Se cargaron {len(dataframes)} datasets.")
# Out:
# /tmp/ipykernel_1799/992463505.py:11: DtypeWarning: Columns (81,82,83,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /tmp/ipykernel_1799/992463505.py:11: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /tmp/ipykernel_1799/992463505.py:11: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /tmp/ipykernel_1799/992463505.py:11: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Se cargaron 10 datasets.
